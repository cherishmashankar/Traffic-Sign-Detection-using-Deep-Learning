# %% [markdown]
# ## Importing packages

# %%
import numpy as np
import random
import os
import cv2 as cv
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.models import Sequential, load_model
from keras.layers import Conv2D, Dense, Flatten, Rescaling, AveragePooling2D, Dropout

# %% [markdown]
# ## Reading and Pre-processing image files

# %%
images = []
labels = []
classes = 43

current_path = 'GTSRB_Final_Training_Images/GTSRB/Final_Training/Images/'

for i in range(classes):
    path = os.path.join(current_path, str(str(i).zfill(5)))
    img_folder = os.listdir(path)
    for j in img_folder:
        try:
            image = cv.imread(str(path+'/'+j))
            image = cv.resize(image, (32, 32))
            image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
            image = np.array(image)
            images.append(image)
            label = np.zeros(classes)
            label[i] = 1.0
            labels.append(label)
        except:
            pass

# %% [markdown]
# ## Feature Scaling or Normalisation

# %%
images = np.array(images)
images = images/255
labels = np.array(labels)
print('Images shape:', images.shape)
print('Labels shape:', labels.shape)
# Out:
# Images shape: (39209, 32, 32)
# Labels shape: (39209, 43)

# %% [markdown]
# ## Splitting dataset into Train and Test Subset

# %%
X = images.astype(np.float32)
y = labels.astype(np.float32)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (31367, 32, 32)
# y_train shape: (31367, 43)
# X_test shape: (7842, 32, 32)
# y_test shape: (7842, 43)

# %% [markdown]
# ## Plotting the Image

# %%
plt.figure(figsize=(12, 12))
start_index = 0
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    label = np.argmax(y_train[start_index+i])
    
    plt.xlabel('i={}, label={}'.format(start_index+i, label))
    plt.imshow(X_train[start_index+i], cmap='gray')
plt.show()

# %% [markdown]
# ## Building a LeNet Model

# %%
# Building the model
model = Sequential([
    Rescaling(1, input_shape=(32, 32, 1)),
    Conv2D(filters=6, kernel_size=(5, 5), activation='relu'),
    AveragePooling2D(pool_size=(2, 2)),
    Conv2D(filters=16, kernel_size=(5, 5), activation='relu'),
    AveragePooling2D(pool_size=(2, 2)),
    Conv2D(filters=120, kernel_size=(5, 5), activation='relu'),
    Dropout(0.2),
    Flatten(),
    Dense(units=120, activation='relu'),
    Dense(units=43, activation='softmax')
])

# Compilation of the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Model architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 32, 32, 1)         0
#
#  conv2d (Conv2D)             (None, 28, 28, 6)         156
#
#  average_pooling2d (AverageP  (None, 14, 14, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_1 (Averag  (None, 5, 5, 16)         0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 120)         48120
#
#  dropout (Dropout)           (None, 1, 1, 120)         0
#
#  flatten (Flatten)           (None, 120)               0
#
#  dense (Dense)               (None, 120)               14520
#
#  dense_1 (Dense)             (None, 43)                5203
#
# =================================================================
# Total params: 70,415
# Trainable params: 70,415
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training the Model

# %%
history = model.fit(X_train, y_train, epochs=50,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 981/981 [==============================] - 13s 9ms/step - loss: 1.7443 - accuracy: 0.5065 - val_loss: 0.6208 - val_accuracy: 0.8178
# Epoch 2/50
# 981/981 [==============================] - 9s 9ms/step - loss: 0.6029 - accuracy: 0.8169 - val_loss: 0.4030 - val_accuracy: 0.8822
# Epoch 3/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.4085 - accuracy: 0.8767 - val_loss: 0.2555 - val_accuracy: 0.9290
# Epoch 4/50
# 981/981 [==============================] - 9s 10ms/step - loss: 0.3058 - accuracy: 0.9070 - val_loss: 0.1883 - val_accuracy: 0.9480
# Epoch 5/50
# 981/981 [==============================] - 9s 9ms/step - loss: 0.2443 - accuracy: 0.9262 - val_loss: 0.1418 - val_accuracy: 0.9597
# Epoch 6/50
# 981/981 [==============================] - 9s 9ms/step - loss: 0.2066 - accuracy: 0.9365 - val_loss: 0.1200 - val_accuracy: 0.9672
# Epoch 7/50
# 981/981 [==============================] - 9s 10ms/step - loss: 0.1744 - accuracy: 0.9478 - val_loss: 0.0987 - val_accuracy: 0.9718
# Epoch 8/50
# 981/981 [==============================] - 9s 10ms/step - loss: 0.1520 - accuracy: 0.9538 - val_loss: 0.0983 - val_accuracy: 0.9727
# Epoch 9/50
# 981/981 [==============================] - 9s 9ms/step - loss: 0.1372 - accuracy: 0.9570 - val_loss: 0.0852 - val_accuracy: 0.9765
# Epoch 10/50
# 981/981 [==============================] - 9s 10ms/step - loss: 0.1189 - accuracy: 0.9643 - val_loss: 0.0784 - val_accuracy: 0.9796
# Epoch 11/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.1102 - accuracy: 0.9667 - val_loss: 0.0703 - val_accuracy: 0.9807
# Epoch 12/50
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0973 - accuracy: 0.9697 - val_loss: 0.0671 - val_accuracy: 0.9811
# Epoch 13/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0936 - accuracy: 0.9705 - val_loss: 0.0680 - val_accuracy: 0.9811
# Epoch 14/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0817 - accuracy: 0.9730 - val_loss: 0.0628 - val_accuracy: 0.9837
# Epoch 15/50
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0797 - accuracy: 0.9740 - val_loss: 0.0521 - val_accuracy: 0.9869
# Epoch 16/50
# 981/981 [==============================] - 9s 10ms/step - loss: 0.0735 - accuracy: 0.9766 - val_loss: 0.0556 - val_accuracy: 0.9855
# Epoch 17/50
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0606 - accuracy: 0.9809 - val_loss: 0.0458 - val_accuracy: 0.9888
# Epoch 18/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0649 - accuracy: 0.9786 - val_loss: 0.0528 - val_accuracy: 0.9876
# Epoch 19/50
# 981/981 [==============================] - 9s 10ms/step - loss: 0.0593 - accuracy: 0.9815 - val_loss: 0.0513 - val_accuracy: 0.9887
# Epoch 20/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0556 - accuracy: 0.9819 - val_loss: 0.0609 - val_accuracy: 0.9843
# Epoch 21/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0500 - accuracy: 0.9836 - val_loss: 0.0510 - val_accuracy: 0.9866
# Epoch 22/50
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0515 - accuracy: 0.9838 - val_loss: 0.0537 - val_accuracy: 0.9875
# Epoch 23/50
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0508 - accuracy: 0.9837 - val_loss: 0.0559 - val_accuracy: 0.9875
# Epoch 24/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0428 - accuracy: 0.9857 - val_loss: 0.0477 - val_accuracy: 0.9885
# Epoch 25/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0437 - accuracy: 0.9850 - val_loss: 0.0480 - val_accuracy: 0.9887
# Epoch 26/50
# 981/981 [==============================] - 11s 12ms/step - loss: 0.0405 - accuracy: 0.9869 - val_loss: 0.0447 - val_accuracy: 0.9894
# Epoch 27/50
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0474 - accuracy: 0.9853 - val_loss: 0.0476 - val_accuracy: 0.9881
# Epoch 28/50
# 981/981 [==============================] - 12s 12ms/step - loss: 0.0363 - accuracy: 0.9883 - val_loss: 0.0578 - val_accuracy: 0.9866
# Epoch 29/50
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0361 - accuracy: 0.9884 - val_loss: 0.0474 - val_accuracy: 0.9881
# Epoch 30/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0373 - accuracy: 0.9883 - val_loss: 0.0404 - val_accuracy: 0.9899
# Epoch 31/50
# 981/981 [==============================] - 12s 12ms/step - loss: 0.0354 - accuracy: 0.9888 - val_loss: 0.0486 - val_accuracy: 0.9894
# Epoch 32/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0349 - accuracy: 0.9883 - val_loss: 0.0464 - val_accuracy: 0.9904
# Epoch 33/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0321 - accuracy: 0.9892 - val_loss: 0.0530 - val_accuracy: 0.9857
# Epoch 34/50
# 981/981 [==============================] - 10s 11ms/step - loss: 0.0323 - accuracy: 0.9891 - val_loss: 0.0433 - val_accuracy: 0.9902
# Epoch 35/50
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0289 - accuracy: 0.9905 - val_loss: 0.0428 - val_accuracy: 0.9916
# Epoch 36/50
# 981/981 [==============================] - 10s 11ms/step - loss: 0.0353 - accuracy: 0.9889 - val_loss: 0.0413 - val_accuracy: 0.9901
# Epoch 37/50
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0275 - accuracy: 0.9907 - val_loss: 0.0432 - val_accuracy: 0.9904
# Epoch 38/50
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0290 - accuracy: 0.9912 - val_loss: 0.0428 - val_accuracy: 0.9920
# Epoch 39/50
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0296 - accuracy: 0.9906 - val_loss: 0.0403 - val_accuracy: 0.9913
# Epoch 40/50
# 981/981 [==============================] - 9s 9ms/step - loss: 0.0293 - accuracy: 0.9908 - val_loss: 0.0413 - val_accuracy: 0.9918
# Epoch 41/50
# 981/981 [==============================] - 10s 11ms/step - loss: 0.0272 - accuracy: 0.9913 - val_loss: 0.0447 - val_accuracy: 0.9904
# Epoch 42/50
# 981/981 [==============================] - 11s 11ms/step - loss: 0.0266 - accuracy: 0.9913 - val_loss: 0.0422 - val_accuracy: 0.9903
# Epoch 43/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0297 - accuracy: 0.9904 - val_loss: 0.0346 - val_accuracy: 0.9921
# Epoch 44/50
# 981/981 [==============================] - 12s 12ms/step - loss: 0.0250 - accuracy: 0.9920 - val_loss: 0.0403 - val_accuracy: 0.9915
# Epoch 45/50
# 981/981 [==============================] - 10s 11ms/step - loss: 0.0256 - accuracy: 0.9915 - val_loss: 0.0422 - val_accuracy: 0.9915
# Epoch 46/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0227 - accuracy: 0.9929 - val_loss: 0.0416 - val_accuracy: 0.9916
# Epoch 47/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0283 - accuracy: 0.9904 - val_loss: 0.0465 - val_accuracy: 0.9904
# Epoch 48/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0253 - accuracy: 0.9915 - val_loss: 0.0432 - val_accuracy: 0.9920
# Epoch 49/50
# 981/981 [==============================] - 10s 10ms/step - loss: 0.0237 - accuracy: 0.9925 - val_loss: 0.0388 - val_accuracy: 0.9922
# Epoch 50/50
# 981/981 [==============================] - 9s 10ms/step - loss: 0.0232 - accuracy: 0.9928 - val_loss: 0.0406 - val_accuracy: 0.9923

# %% [markdown]
# ## Evaluating the trained results

# %%
val_loss, val_acc = model.evaluate(X_test, y_test, verbose=2)
print('\nValifdation accuracy:', val_acc)
print('\nValidation loss:', val_loss)
# Out:
# 246/246 - 1s - loss: 0.0406 - accuracy: 0.9923 - 916ms/epoch - 4ms/step
#
# Valifdation accuracy: 0.9923489093780518
#
# Validation loss: 0.040560975670814514

# %% [markdown]
# ## Plotting Accuarcy and Error curve for train and test set

# %%
plt.figure(0)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.8, 1])
plt.legend(loc='lower right')

plt.figure(1)
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 0.2])
plt.legend(loc='lower right')

# %% [markdown]
# ## Prediction for Samples

# %%
preds = model.predict(X_test)

plt.figure(figsize=(12, 12))
start_index = random.randint(0, 7800)
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    pred = np.argmax(preds[start_index+i])
    gt = np.argmax(y_test[start_index+i])
    
    col = 'g'
    if pred != gt:
        col = 'r'
    
    plt.xlabel('i={}, pred={}, gt={}'.format(start_index+i, pred, gt), color=col)
    plt.imshow(X_test[start_index+i], cmap='gray')
plt.show()
# Out:
# 246/246 [==============================] - 1s 4ms/step

# %% [markdown]
# ## Save the Model

# %%
model.save('german_traffic_sign_model.h5')
